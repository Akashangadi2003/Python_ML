# %% [markdown]
# LINEAR REGG

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
x = df['longitude'].values
y = df['latitude'].values
plt.scatter(x, y)
plt.xlabel("LONGITUDE")
plt.ylabel("LATITUDE")
plt.show()
x_mean=np.mean(x)
y_mean=np.mean(y)
x_mean,y_mean

num=0
deno=0
for i in range (len(x)):
    num +=(x[i]-x_mean)*(y[i]-y_mean)
    deno+=(x[i]-x_mean)**2

coeff=num/deno
print("COEFFI=",coeff)
intercept=y_mean-(coeff*x_mean)
print("INTERCEPT=",intercept)
y_pred=coeff*x+intercept
y_pred
plt.scatter(x,y,c="red")
plt.plot(x,y_pred)
plt.show
# Out:
# COEFFI= -0.9874899135195284
# INTERCEPT= -82.45773876586958
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv('/Experience-Salary.csv')
x=data['exp(in months)'].values
y=data['salary(in thousands)'].values
print("MONTHS:",x)
print("SALARY:" ,y)
plt.scatter(x,y)
plt.show()

def model(X,Y,ler_rate,itter):
  m=Y.size
  theta=np.zeros((2,1))

  for i in range(itter):
    y_pred=np.dot(X,theta)
    cost=(1/(2*m))*np.sum(np.square(y_pred - Y))

    d_theta=(1/m)*np.dot(X.T,y_pred-Y)
    theta=theta-ler_rate*d_theta
    return theta

    itter=100
    ler_rate=0.00000005
    theta= model(X, Y, ler_rate = ler_rate, itter = itter)
plt.scatter(x,y,c="red")
plt.plot(x,y_pred)
# Out:
# MONTHS: [18.29029332 17.02340669 26.34361348 19.10583387 27.74251647 31.67117131
#  14.18639863 29.932845   32.84132735 26.87386911 41.51380791 32.20117764
#  34.73822584 27.51493135 25.76125817 36.92531809 23.7470025  24.09348782
#  16.13380215 23.252563   25.63058204 27.59918582 22.92110427 20.05168098
#  24.98304725 33.91865279 44.45485384 19.58633061 18.51115733 31.54165401
#  31.71843486 18.32610619 21.34802336 26.91006992 34.93973987 27.33055795
#  21.36414187 29.78202486 15.74794461 14.39682659 28.50094976 21.88009726
#  10.59131485 17.12255632 36.48815058 19.5314334  34.00288198 43.27144687
#  20.47647992]
# SALARY: [16.52182491 11.66623372 23.16725455 20.87714542 23.16623569 32.96625076
#  15.29416954 33.15946113 32.0326529  32.34778358 38.24687556 22.77360262
#  39.55484071 26.92287021 28.11647711 32.53300295 26.04333166 24.08604097
#  20.91991068 21.04163596 25.71871117 25.59144379 28.90651651 18.3044055
# ...
